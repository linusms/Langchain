# %% [markdown]
# <a href="https://colab.research.google.com/github/linusms/Langchain/blob/main/HuggingFace_model_download.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install langchain_huggingface
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 408.7/408.7 kB 10.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: langchain-core
#     Found existing installation: langchain-core 0.3.13
#     Uninstalling langchain-core-0.3.13:
#       Successfully uninstalled langchain-core-0.3.13
# ...

# %%
from huggingface_hub import snapshot_download
import os

authorization_token="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"

current_path=os.getcwd()

model_name="meta-llama/Llama-3.2-3B-Instruct"
local_dir=current_path

snapshot_download(repo_id=model_name, cache_dir=local_dir, use_auth_token=authorization_token)
# Out:
# Fetching 16 files:   0%|          | 0/16 [00:00<?, ?it/s]
# consolidated.00.pth:   0%|          | 0.00/6.43G [00:00<?, ?B/s]
# .gitattributes:   0%|          | 0.00/1.52k [00:00<?, ?B/s]
# USE_POLICY.md:   0%|          | 0.00/6.02k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/878 [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/1.46G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/189 [00:00<?, ?B/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/4.97G [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/20.9k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/296 [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/2.18M [00:00<?, ?B/s]
# original/orig_params.json:   0%|          | 0.00/220 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/54.5k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/9.09M [00:00<?, ?B/s]
# ...

# %%
from transformers import AutoModel, AutoTokenizer

model_path='/content/models--meta-llama--Llama-3.2-3B-Instruct/snapshots/0cb88a4f764b7a12671c53f0838cd831a0843b95'

try:
    model = AutoModel.from_pretrained(model_path)
    tokenizer = AutoTokenizer.from_pretrained(model_path)
    print("모델 로드 성공")
except Exception as e:
    print(f"모델 로드 실패: {e}")
    print("필요한 라이브러리를 설치해야 할 수 있습니다.")
# Out:
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]

# %%
text = "안녕하세요, Hugging Face!"
inputs = tokenizer(text, return_tensors="pt")
outputs = model(**inputs)

# %%
# !zip -r /content/models--meta-llama--Llama-3.2-3B-Instruct.zip /content/models--meta-llama--Llama-3.2-3B-Instruct
# Out:
#   adding: content/models--meta-llama--Llama-3.2-3B-Instruct/ (stored 0%)
#   adding: content/models--meta-llama--Llama-3.2-3B-Instruct/snapshots/ (stored 0%)
#   adding: content/models--meta-llama--Llama-3.2-3B-Instruct/snapshots/0cb88a4f764b7a12671c53f0838cd831a0843b95/ (stored 0%)
#   adding: content/models--meta-llama--Llama-3.2-3B-Instruct/snapshots/0cb88a4f764b7a12671c53f0838cd831a0843b95/original/ (stored 0%)
#   adding: content/models--meta-llama--Llama-3.2-3B-Instruct/snapshots/0cb88a4f764b7a12671c53f0838cd831a0843b95/original/tokenizer.model (deflated 54%)
#   adding: content/models--meta-llama--Llama-3.2-3B-Instruct/snapshots/0cb88a4f764b7a12671c53f0838cd831a0843b95/original/params.json (deflated 35%)
#   adding: content/models--meta-llama--Llama-3.2-3B-Instruct/snapshots/0cb88a4f764b7a12671c53f0838cd831a0843b95/original/consolidated.00.pth (deflated 21%)
# ...

# %%
# !python -m venv .env

# !source .env/bin/activate

# !pip install transformers torch

# %%
# !pip freeze > requirements.txt

# %%
# !pip download -r requirements.txt -d ./wheels

# %%
from google.colab import files

files.download('models--meta-llama--Llama-3.2-3B-Instruct.zip')
